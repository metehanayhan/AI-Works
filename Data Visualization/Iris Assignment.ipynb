# %% [markdown]
# # METEHAN AYHAN IRIS HOMEWORK

# %% [markdown]
# # "Human Learning" with iris data
#
# Can you predict the species of an iris using petal and sepal measurements?
#
# TASKS:
# 1. Read iris data into a pandas DataFrame, including column names.
# 2. Gather some basic information about the data.
# 3. Use groupby, sorting, and/or plotting to look for differences between species.
# 4. Come up with a set of rules that could be used to predict species based upon measurements.
#
# BONUS: Define a function that accepts a row of data and returns a predicted species.
# Then, use that function to make predictions for all existing rows of data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Task 1

# %%
# read the iris data into a pandas DataFrame, including column names
df = pd.read_csv('iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Task 2

# %%
# gather basic information
df.info()
df.describe()

df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## Task 3

# %%
# use groupby to look for differences between the species
grouped = df.groupby('species')
grouped.describe()
grouped.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 101           5.8          2.7           5.1          1.9   virginica
# 102           7.1          3.0           5.9          2.1   virginica
# 103           6.3          2.9           5.6          1.8   virginica
# 104           6.5          3.0           5.8          2.2   virginica

# %%
# use sorting to look for differences between the species
df_sort = df.sort_values(by=['species', 'sepal_length'])
df_sort
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# sepal width'i türler arası ayrım yapmada kullanamayız.

# %%
df_sort2 = df.sort_values(by=['petal_width'])
df_sort2.head(60)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 32           5.2          4.1           1.5          0.1      setosa
# 13           4.3          3.0           1.1          0.1      setosa
# 37           4.9          3.1           1.5          0.1      setosa
# 9            4.9          3.1           1.5          0.1      setosa
# 12           4.8          3.0           1.4          0.1      setosa
# 34           4.9          3.1           1.5          0.1      setosa
# 0            5.1          3.5           1.4          0.2      setosa
# 27           5.2          3.5           1.5          0.2      setosa
# 28           5.2          3.4           1.4          0.2      setosa
# 29           4.7          3.2           1.6          0.2      setosa
# 30           4.8          3.1           1.6          0.2      setosa
# 33           5.5          4.2           1.4          0.2      setosa
# 36           5.5          3.5           1.3          0.2      setosa
# 38           4.4          3.0           1.3          0.2      setosa
# 39           5.1          3.4           1.5          0.2      setosa
# 42           4.4          3.2           1.3          0.2      setosa
# 46           5.1          3.8           1.6          0.2      setosa
# 47           4.6          3.2           1.4          0.2      setosa
# 48           5.3          3.7           1.5          0.2      setosa
# 49           5.0          3.3           1.4          0.2      setosa
# 25           5.0          3.0           1.6          0.2      setosa
# 24           4.8          3.4           1.9          0.2      setosa
# 35           5.0          3.2           1.2          0.2      setosa
# 3            4.6          3.1           1.5          0.2      setosa
# 2            4.7          3.2           1.3          0.2      setosa
# 7            5.0          3.4           1.5          0.2      setosa
# 8            4.4          2.9           1.4          0.2      setosa
# 10           5.4          3.7           1.5          0.2      setosa
# 4            5.0          3.6           1.4          0.2      setosa
# 11           4.8          3.4           1.6          0.2      setosa
# 14           5.8          4.0           1.2          0.2      setosa
# 1            4.9          3.0           1.4          0.2      setosa
# 20           5.4          3.4           1.7          0.2      setosa
# 22           4.6          3.6           1.0          0.2      setosa
# 17           5.1          3.5           1.4          0.3      setosa
# 18           5.7          3.8           1.7          0.3      setosa
# 19           5.1          3.8           1.5          0.3      setosa
# 6            4.6          3.4           1.4          0.3      setosa
# 40           5.0          3.5           1.3          0.3      setosa
# 41           4.5          2.3           1.3          0.3      setosa
# 45           4.8          3.0           1.4          0.3      setosa
# 15           5.7          4.4           1.5          0.4      setosa
# 16           5.4          3.9           1.3          0.4      setosa
# 26           5.0          3.4           1.6          0.4      setosa
# 5            5.4          3.9           1.7          0.4      setosa
# 21           5.1          3.7           1.5          0.4      setosa
# 44           5.1          3.8           1.9          0.4      setosa
# 31           5.4          3.4           1.5          0.4      setosa
# 23           5.1          3.3           1.7          0.5      setosa
# 43           5.0          3.5           1.6          0.6      setosa
# 79           5.7          2.6           3.5          1.0  versicolor
# 67           5.8          2.7           4.1          1.0  versicolor
# 81           5.5          2.4           3.7          1.0  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 93           5.0          2.3           3.3          1.0  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
# 80           5.5          2.4           3.8          1.1  versicolor
# 69           5.6          2.5           3.9          1.1  versicolor

# %%
df_sort2.iloc[50:110]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 79            5.7          2.6           3.5          1.0  versicolor
# 67            5.8          2.7           4.1          1.0  versicolor
# 81            5.5          2.4           3.7          1.0  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor
# 57            4.9          2.4           3.3          1.0  versicolor
# 93            5.0          2.3           3.3          1.0  versicolor
# 60            5.0          2.0           3.5          1.0  versicolor
# 98            5.1          2.5           3.0          1.1  versicolor
# 80            5.5          2.4           3.8          1.1  versicolor
# 69            5.6          2.5           3.9          1.1  versicolor
# 95            5.7          3.0           4.2          1.2  versicolor
# 92            5.8          2.6           4.0          1.2  versicolor
# 90            5.5          2.6           4.4          1.2  versicolor
# 82            5.8          2.7           3.9          1.2  versicolor
# 73            6.1          2.8           4.7          1.2  versicolor
# 96            5.7          2.9           4.2          1.3  versicolor
# 89            5.5          2.5           4.0          1.3  versicolor
# 97            6.2          2.9           4.3          1.3  versicolor
# 88            5.6          3.0           4.1          1.3  versicolor
# 87            6.3          2.3           4.4          1.3  versicolor
# 99            5.7          2.8           4.1          1.3  versicolor
# 94            5.6          2.7           4.2          1.3  versicolor
# 74            6.4          2.9           4.3          1.3  versicolor
# 71            6.1          2.8           4.0          1.3  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 55            5.7          2.8           4.5          1.3  versicolor
# 58            6.6          2.9           4.6          1.3  versicolor
# 64            5.6          2.9           3.6          1.3  versicolor
# 134           6.1          2.6           5.6          1.4   virginica
# 50            7.0          3.2           4.7          1.4  versicolor
# 59            5.2          2.7           3.9          1.4  versicolor
# 63            6.1          2.9           4.7          1.4  versicolor
# 91            6.1          3.0           4.6          1.4  versicolor
# 76            6.8          2.8           4.8          1.4  versicolor
# 75            6.6          3.0           4.4          1.4  versicolor
# 65            6.7          3.1           4.4          1.4  versicolor
# 119           6.0          2.2           5.0          1.5   virginica
# 133           6.3          2.8           5.1          1.5   virginica
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 78            6.0          2.9           4.5          1.5  versicolor
# 72            6.3          2.5           4.9          1.5  versicolor
# 84            5.4          3.0           4.5          1.5  versicolor
# 61            5.9          3.0           4.2          1.5  versicolor
# 68            6.2          2.2           4.5          1.5  versicolor
# 66            5.6          3.0           4.5          1.5  versicolor
# 86            6.7          3.1           4.7          1.5  versicolor
# 56            6.3          3.3           4.7          1.6  versicolor
# 129           7.2          3.0           5.8          1.6   virginica
# 85            6.0          3.4           4.5          1.6  versicolor
# 83            6.0          2.7           5.1          1.6  versicolor
# 106           4.9          2.5           4.5          1.7   virginica
# 77            6.7          3.0           5.0          1.7  versicolor
# 116           6.5          3.0           5.5          1.8   virginica
# 137           6.4          3.1           5.5          1.8   virginica
# 127           6.1          3.0           4.9          1.8   virginica
# 126           6.2          2.8           4.8          1.8   virginica
# 125           7.2          3.2           6.0          1.8   virginica
# 123           6.3          2.7           4.9          1.8   virginica

# %%
# map species to a numeric value so that plots can be colored by category

# %%
plt.figure(figsize=(12, 6))

# Sepal length vs Sepal width
plt.subplot(1, 2, 1)
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Sepal Length vs Sepal Width')

# Petal length vs Petal width
plt.subplot(1, 2, 2)
sns.scatterplot(data=df, x='petal_length', y='petal_width', hue='species')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title('Petal Length vs Petal Width')

plt.show()

# %% [markdown]
# setosa türü için petal width ve petal lenght verileri yeterli.. ancak 5 virginia verisi versicolor petal width değerinin içine geçmiş durumda..

# %% [markdown]
# ## Task 4

# %% [markdown]
# petal width 0-0,7 arası ise setosa dır.  0.9 ile 1.79 arası versicolor 1.8 ve üzeri virginica.. (farklı olarak 119,133,134,129,106 numaralı türler virginia)
#
# sepal lenght ve widht için (0,2.5) ve (7.0,0) noktaları arasındaki doğrunun üstünde kalan noktalar için setosa diyebiliriz.. diğerleri için yine bir şey söyleyemeyiz.

# %% [markdown]
# ## Bonus

# %%
# define function that accepts a row of data and returns a predicted species
def tahmin(petal_width):
    if petal_width <= 0.7:
        return 'setosa'
    elif 0.9 <= petal_width <= 1.79:
        return 'versicolor'
    elif petal_width >= 1.8:
        return 'virginica'

# 5 deger için yanlış tahmin üretecek..
df['predicted_species'] = df['petal_width'].apply(tahmin)

df[['petal_width', 'predicted_species']]
# Out:
#      petal_width predicted_species
# 0            0.2            setosa
# 1            0.2            setosa
# 2            0.2            setosa
# 3            0.2            setosa
# 4            0.2            setosa
# ..           ...               ...
# 145          2.3         virginica
# 146          1.9         virginica
# 147          2.0         virginica
# 148          2.3         virginica
# 149          1.8         virginica
#
# [150 rows x 2 columns]

# %%
df.iloc[100:150]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# 113           5.7          2.5           5.0          2.0  virginica
# 114           5.8          2.8           5.1          2.4  virginica
# 115           6.4          3.2           5.3          2.3  virginica
# 116           6.5          3.0           5.5          1.8  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 119           6.0          2.2           5.0          1.5  virginica
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#     predicted_species
# 100         virginica
# 101         virginica
# 102         virginica
# 103         virginica
# 104         virginica
# 105         virginica
# 106        versicolor
# 107         virginica
# 108         virginica
# 109         virginica
# 110         virginica
# 111         virginica
# 112         virginica
# 113         virginica
# 114         virginica
# 115         virginica
# 116         virginica
# 117         virginica
# 118         virginica
# 119        versicolor
# 120         virginica
# 121         virginica
# 122         virginica
# 123         virginica
# 124         virginica
# 125         virginica
# 126         virginica
# 127         virginica
# 128         virginica
# 129        versicolor
# 130         virginica
# 131         virginica
# 132         virginica
# 133        versicolor
# 134        versicolor
# 135         virginica
# 136         virginica
# 137         virginica
# 138         virginica
# 139         virginica
# 140         virginica
# 141         virginica
# 142         virginica
# 143         virginica
# 144         virginica
# 145         virginica
# 146         virginica
# 147         virginica
# 148         virginica
# 149         virginica
