# %% [markdown]
# # Metehan Ayhan - Style Cloud ile görselleştirme

# %%
#pip install stylecloud

# %%
import stylecloud as sc
import matplotlib as plt

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='ch.png')

# %%
from IPython.display import Image
Image('ch.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt',icon_name='fas fa-car',output_name='ch2.png')

# %%
Image('ch2.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt',icon_name='fas fa-star-and-crescent',output_name='ch5.png')

# %%
Image('ch5.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt',icon_name='fas fa-star-and-crescent', output_name='ch4.png', background_color="red",colors="white")

# %%
Image('ch4.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt',icon_name='fas fa-fighter-jet', output_name='ch6.png')

# %%
Image('ch6.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt',icon_name='fas fa-helicopter', output_name='ch7.png')

# %%
Image('ch7.png')
